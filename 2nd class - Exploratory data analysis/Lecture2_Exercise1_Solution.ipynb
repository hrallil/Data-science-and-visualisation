# %% [markdown]
# # Data Science and Visualization (RUC F2023)
#
# ## Lecture 2: Exploratory Data Analysis (EDA)

# %% [markdown]
# # Exercise 1

# %% [markdown]
# ## Exercise:
#
# ![image.png](attachment:image.png)
#
# 1. Create a DataFrame object for this table, use None for NULL values.
# 2. Show the DataFrame object.
# 3. Show the index of the DataFrame object.
# 4. Change the index to ['A', 'B', 'C', 'D', 'E', 'F']
# 5. Find the most frequent value of the height column
# 6. Save the data to a .csv file and load/show the data again from the file.

# %% [markdown]
# 1. Create a DataFrame object for this table, use None for NULL values.

# %%
import pandas as pd

data = [['John', 'Male', 3, 96, 15],
        ['Kate', 'Female', 4, 100, 17],
        ['Sebastian', 'Male', 5, 110, 19],
        ['Mads', 'Male', 3, 100, None],
        ['Emil', 'Male', 5, None, 16],
        ['Kelly', 'Female', 4, 100, 15]]

# %%
df = pd.DataFrame(data, columns=['name', 'gender', 'age', 'height', 'weight'])

# %% [markdown]
# 2. Show the DataFrame object.

# %%
df
# Out:
#         name  gender  age  height  weight
# 0       John    Male    3    96.0    15.0
# 1       Kate  Female    4   100.0    17.0
# 2  Sebastian    Male    5   110.0    19.0
# 3       Mads    Male    3   100.0     NaN
# 4       Emil    Male    5     NaN    16.0
# 5      Kelly  Female    4   100.0    15.0

# %%
df.describe(include='all')
# Out:
#         name gender       age      height    weight
# count      6      6  6.000000    5.000000   5.00000
# unique     6      2       NaN         NaN       NaN
# top     John   Male       NaN         NaN       NaN
# freq       1      4       NaN         NaN       NaN
# mean     NaN    NaN  4.000000  101.200000  16.40000
# std      NaN    NaN  0.894427    5.215362   1.67332
# min      NaN    NaN  3.000000   96.000000  15.00000
# 25%      NaN    NaN  3.250000  100.000000  15.00000
# 50%      NaN    NaN  4.000000  100.000000  16.00000
# 75%      NaN    NaN  4.750000  100.000000  17.00000
# max      NaN    NaN  5.000000  110.000000  19.00000

# %% [markdown]
# 3. Show the index of the DataFrame object.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %% [markdown]
# 4. Change the index to ['A', 'B', 'C', 'D', 'E', 'F']

# %%
df.index = ['A', 'B', 'C', 'D', 'E', 'F']

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df
# Out:
#         name  gender  age  height  weight
# A       John    Male    3    96.0    15.0
# B       Kate  Female    4   100.0    17.0
# C  Sebastian    Male    5   110.0    19.0
# D       Mads    Male    3   100.0     NaN
# E       Emil    Male    5     NaN    16.0
# F      Kelly  Female    4   100.0    15.0

# %% [markdown]
# 5. Find the most frequent value of the height column

# %%
df.height.nlargest(1)
# Out:
# 2    110.0
# Name: height, dtype: float64

# %% [markdown]
# 6. Save the data to a .csv file and load/show the data again from the file.

# %%
df.to_csv('C:/Data/dataframe_1.csv')
df_1 = pd.read_csv('C:/Data/dataframe_1.csv', index_col=[0])
df_1
# Out:
#         name  gender  age  height  weight
# A       John    Male    3    96.0    15.0
# B       Kate  Female    4   100.0    17.0
# C  Sebastian    Male    5   110.0    19.0
# D       Mads    Male    3   100.0     NaN
# E       Emil    Male    5     NaN    16.0
# F      Kelly  Female    4   100.0    15.0
